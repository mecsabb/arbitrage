# %%
import graphutils as gu

# %%
gg = gu.GraphGenerator()
g = gg.generate_graph(12,15)
g.add_node("A")
g.add_node("B")
g.add_node("C")

g.add_edge("A", "B", -1)
g.add_edge("B", "C", 4)
g.add_edge("A", "C", 3)

# Run the Bellman-Ford algorithm
execution_time, distance, predecessor = g.bellman_ford("A")

print(f"Bellman-Ford algorithm executed in {execution_time:.5f} seconds")
print("Distance:", distance)
print("Predecessor:", predecessor)
# Out:
# Bellman-Ford algorithm executed in 0.00000 seconds
# Distance: {'A': 0, 'B': -1, 'C': 3, 'D': inf, 'E': inf, 'F': inf, 'G': 13.440984577399977, 'H': 16.6627583979484, 'I': 6.17237637568233, 'J': inf, 'K': inf, 'L': 16.02775144460654}
# Predecessor: {'A': None, 'B': 'A', 'C': 'A', 'D': None, 'E': None, 'F': None, 'G': 'I', 'H': 'G', 'I': 'A', 'J': None, 'K': None, 'L': 'G'}

# %%
nx.draw_kamada_kawai(g.graph)

# %%
nx.draw_shell(g.graph)

# %%
nx.draw_networkx_labels(g.graph)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ellio\python\QMIND ARB\arbitrage\coz\ElliotMCTS\mcts.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ellio/python/QMIND%20ARB/arbitrage/coz/ElliotMCTS/mcts.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> nx.draw_networkx_labels(g.graph)
#
# TypeError: draw_networkx_labels() missing 1 required positional argument: 'pos'

# %%
import networkx as nx
import  matplotlib.pyplot as plt

# %%
G = nx.petersen_graph()
nx.draw(G)
# subax1 = plt.subplot(121)
# nx.draw(g.graph, with_labels=True, font_weight='bold')
# subax2 = plt.subplot(122)
# nx.draw_shell(g.graph, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')
